# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# %load_ext sempy
import sempy.fabric as fabric
import sempy_labs as sempy_labs
from sempy.fabric import FabricDataFrame
from pyspark.sql.functions import current_timestamp
import pandas as pd
from pyspark.sql.functions import when, col, lit
from pyspark.sql.types import StringType
import requests
# Out:
# StatementMeta(, 747ed321-b927-44c5-bb87-43759e5848fb, 6, Finished, Available, Finished)

# %%
#List workspaces

listworkspaces = fabric.list_workspaces()

# Transform column names for LH compatibility
listworkspaces.columns = listworkspaces.columns.str.replace('[^a-zA-Z0-9]', '', regex=True)
listworkspaces.columns = listworkspaces.columns.str.replace('[ ]', '', regex=True)

display(listworkspaces)

FabricDataFrame(listworkspaces).to_lakehouse_table("demoworkspaces", mode="append")
# Out:
# StatementMeta(, 747ed321-b927-44c5-bb87-43759e5848fb, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, f9efcf5c-061b-43e6-bfe3-cca0b5b32bf3)

# %%
#List items

listitems = fabric.list_items(workspace="Tjek - Development")

display( listitems)

# Filter the dataframe
filtered_listitems = listitems[(listitems['Display Name'].str.contains('Metrics', case=False)) & (listitems['Type'] == 'SemanticModel')]

display(filtered_listitems)
# Out:
# StatementMeta(, 747ed321-b927-44c5-bb87-43759e5848fb, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 54d00c66-47f7-485a-a936-95f78bae4a65)
# SynapseWidget(Synapse.DataFrame, 232728d0-edd1-40bf-8641-70e1f3af7406)

# %%
#List tables from data

listreports = fabric.list_reports()

display(listreports)
# Out:
# StatementMeta(, 747ed321-b927-44c5-bb87-43759e5848fb, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, f3024eef-99f7-4291-98b0-53954b4135b8)

# %%
"List tables in usage metrics model"

df_listtables = fabric.list_tables(dataset="185044e2-1f4e-4adf-b5e6-f2716ae74e27")

display(df_listtables)
# Out:
# StatementMeta(, 747ed321-b927-44c5-bb87-43759e5848fb, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 458843b8-96c8-45bd-a5ef-8aefa28eec16)

# %%
"List report views"

df_reportpageviews = fabric.read_table(dataset="185044e2-1f4e-4adf-b5e6-f2716ae74e27",table="Report page views")



# Code generated by Data Wrangler for pandas DataFrame

def clean_data(df_reportpageviews):
    # Created column 'Counter' from formula
    df_reportpageviews['Counter'] = 1
    return df_reportpageviews

df_reportpageviews_clean = clean_data(df_reportpageviews.copy())
df_reportpageviews_clean.head()

display(df_reportpageviews_clean)
# Out:
# StatementMeta(, 747ed321-b927-44c5-bb87-43759e5848fb, 13, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 63939d46-ebde-4c07-a924-14d3e685af4a)
